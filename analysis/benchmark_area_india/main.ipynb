# %% [markdown]
# # Benchmark: Area computation
#
# Benchmark comparing area computation across:
# * [georust/geo](https://lib.rs/crates/geo) crate
# * The [geos C library](https://trac.osgeo.org/geos/), used through high-level Rust bindings via the [geos](https://lib.rs/crates/geos) crate

# %% [markdown]
# # Prerequisites
#
# Generate data:
#
# ```sh
# cd harness
# cargo run --release --bin benchmark_area_india -- --out-file ../analysis/benchmark_area_india/data.json --geojson-file ../data/india_districts/polbnda_ind.geojson --iterations 10
# ```

# %%
import os
data_absolute_path = os.path.join(os.getcwd(), 'data.json')
# %run ../common/benchmark_analysis.ipynb
# Out:
# ### Loading data from /mnt/data/source/explore-georust/analysis/benchmark_area_india/data.json
# ### Statistics: Raw data
#         duration.total_ms
# program               geo
# count           10.000000
# mean           136.639182
# std             49.870136
# min             97.095856
# 25%             97.873057
# 50%            118.887978
# 75%            154.169703
# max            238.121444
# ### Statistics: After outlier removal
#         duration.total_ms
# program               geo
# count            9.000000
# mean           125.363375
# std             36.980282
# min             97.095856
# 25%             97.857234
# 50%             98.064859
# 75%            142.936037
# max            199.630456
# ## Absolute difference in runtimes compared to geo
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /mnt/data/source/explore-georust/analysis/common/benchmark_analysis.ipynb in <module>
#       4 diffs = diffs.iloc[:, 1:]
#       5 print('## Absolute difference in runtimes compared to ' + baseline)
# ----> 6 print(diffs.describe())
#       7 diffs.plot(y='difference_ms', kind='line',
#       8            title='Runtime difference w.r.t.' + baseline + ' (milliseconds)')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10027             exclude=exclude,
#   10028             datetime_is_numeric=datetime_is_numeric,
# > 10029             percentiles=percentiles,
#   10030         )
#   10031
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      90             include=include,
#      91             exclude=exclude,
# ---> 92             datetime_is_numeric=datetime_is_numeric,
#      93         )
#      94
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/describe.py in __init__(self, obj, include, exclude, datetime_is_numeric)
#     163
#     164         if obj.ndim == 2 and obj.columns.size == 0:
# --> 165             raise ValueError("Cannot describe a DataFrame without columns")
#     166
#     167         super().__init__(obj, datetime_is_numeric=datetime_is_numeric)
#
# ValueError: Cannot describe a DataFrame without columns
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6807/765141118.py in <module>
#       1 import os
#       2 data_absolute_path = os.path.join(os.getcwd(), 'data.json')
# ----> 3 get_ipython().run_line_magic('run', '../common/benchmark_analysis.ipynb')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2362                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363             with self.builtin_trap:
# -> 2364                 result = fn(*args, **kwargs)
#    2365             return result
#    2366
#
# /usr/local/lib/python3.7/dist-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     733             with preserve_keys(self.shell.user_ns, '__file__'):
#     734                 self.shell.user_ns['__file__'] = filename
# --> 735                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     736             return
#     737
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2849                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2850                     if raise_exceptions:
# -> 2851                         result.raise_error()
#    2852                     elif not result.success:
#    2853                         break
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_6807/3418559477.py in <module>
#       4 diffs = diffs.iloc[:, 1:]
#       5 print('## Absolute difference in runtimes compared to ' + baseline)
# ----> 6 print(diffs.describe())
#       7 diffs.plot(y='difference_ms', kind='line',
#       8            title='Runtime difference w.r.t.' + baseline + ' (milliseconds)')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10027             exclude=exclude,
#   10028             datetime_is_numeric=datetime_is_numeric,
# > 10029             percentiles=percentiles,
#   10030         )
#   10031
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      90             include=include,
#      91             exclude=exclude,
# ---> 92             datetime_is_numeric=datetime_is_numeric,
#      93         )
#      94
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/describe.py in __init__(self, obj, include, exclude, datetime_is_numeric)
#     163
#     164         if obj.ndim == 2 and obj.columns.size == 0:
# --> 165             raise ValueError("Cannot describe a DataFrame without columns")
#     166
#     167         super().__init__(obj, datetime_is_numeric=datetime_is_numeric)
#
# ValueError: Cannot describe a DataFrame without columns
