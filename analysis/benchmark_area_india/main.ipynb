# %% [markdown]
# # Benchmark: Area computation
#
# Benchmark comparing area computation across:
# * [georust/geo](https://lib.rs/crates/geo) crate
# * The [geos C library](https://trac.osgeo.org/geos/), used through high-level Rust bindings via the [geos](https://lib.rs/crates/geos) crate

# %% [markdown]
# # Prerequisites
#
# Generate data:
#
# ```sh
# cd harness
# cargo run --release --bin benchmark_area_india -- --out-file ../analysis/benchmark_area_india/data.json --geojson-file ../data/india_districts/polbnda_ind.geojson --iterations 100
# ```

# %%
import os
data_absolute_path = os.path.join(os.getcwd(), 'data.json')
# %run ../common/benchmark_analysis.ipynb
# Out:
# ### Loading data from /mnt/data/source/explore-georust/analysis/benchmark_area_india/data.json
# ### Statistics: Raw data
#         duration.total_ms
# program               geo        geos
# count          100.000000  100.000000
# mean            98.949498  228.933698
# std              4.904944   27.760224
# min             95.722608  216.761919
# 25%             96.955820  219.732396
# 50%             97.359153  220.635514
# 75%             98.188053  223.514482
# max            118.916740  447.159040
# ### Statistics: After outlier removal
#         duration.total_ms
# program               geo        geos
# count           92.000000   92.000000
# mean            97.733034  223.197371
# std              1.857615    8.273940
# min             95.722608  216.761919
# 25%             96.904561  219.653493
# 50%             97.286515  220.344419
# 75%             97.964527  222.620411
# max            108.423621  261.245777
# ## Absolute difference in runtimes compared to geo
#         difference_ms
# program          geos
# count       92.000000
# mean       125.464336
# std          7.567935
# min        111.247591
# 25%        122.414640
# 50%        123.370163
# 75%        124.877700
# max        162.305857
# ## Relative difference (percent) in runtimes compared to geo
#         relative_difference_percent
# program                        geos
# count                     92.000000
# mean                     128.378427
# std                        7.257686
# min                      102.604571
# 25%                      125.809804
# 50%                      127.037123
# 75%                      128.454718
# max                      164.044864
